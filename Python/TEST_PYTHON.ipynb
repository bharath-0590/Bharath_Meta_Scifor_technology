# %% [markdown]
# Basic concepts
#
# B1.Python has several data types can define the kind of value a variable can hold.

# %%
'''1.Integer:
           Whole numbers, positive r negative, without a decimal point
'''
num = 15
print(num, type(num))


'''2.Float: represents decimal numbers'''

val = 2.15
print(f'{val}, {type(val)}')

'''3.String: represents a sequence of characters'''

word = 'Technology'
print(word, type(word))

'''4.List: Ordered, mutable collections of items. enclosed with []'''

names = ['bharath', 'vijaya', 'nani', 'prabha']
print(names)

'''5.Tuple: represents ordered, immutable collections of items. Once cretaed values then cannot be changed. enclosed with ()'''

coordinates = (10.5, 20.5)
colors = ("red", "green", "blue")
print(coordinates, colors, type(coordinates))

'''6.Dictionary: Unordered collection of key-value pairs'''

person = {'name':'kumar', 'age': 24 }
print(person)

'''6.Set: Unordered collection of unique items'''

numbers = {10, 20, 30, 40, 50}
print(numbers)
# Out:
# 15 <class 'int'>
# 2.15, <class 'float'>
# Technology <class 'str'>
# ['bharath', 'vijaya', 'nani', 'prabha']
# (10.5, 20.5) ('red', 'green', 'blue') <class 'tuple'>
# {'name': 'kumar', 'age': 24}
# {50, 20, 40, 10, 30}

# %% [markdown]
# B2.difference btnwn list tuple and set

# %%
'''List: mutable, ordered, allows duplicates'''

lst = [10,20,30,40,50]           #list

'''Tuple: Immutable, ordered, allows duplicates.'''

tpl = (1,2,3,4,1,3)             #tuple

'''Set: mutable, unordered, only unique elements'''
st = {1,2,3,4,1,2}              #set (duplicates removed)

# %% [markdown]
# B3. In Python, exceptions are handled using try, except, else, and finally blocks, which allow you to manage errors gracefully.

# %%
''' try: The block of code to be executed, where exceptions might occur.
    except: The block that handles the exception if one is raised.
    else: Executes if no exceptions are raised in the try block.
    finally: Executes code no matter what, whether an exception occurs or not.
    Custom Exception: You can define your own exceptions by subclassing the Exception class.
'''

try:
    num = int(input("Enter a number: "))
    result = 10 / num
except ZeroDivisionError:
    print("Cannot divide by zero!")
except ValueError:
    print("Invalid input, please enter a number.")
else:
    print("Division successful:", result)
finally:
    print("Execution completed.")
# Out:
# Enter a number: 20
# Division successful: 0.5
# Execution completed.

# %% [markdown]
# B4.
# Decorators modify the behavior of functions or methods.

# %%
def decorator(func):
    def wrapper():
        print("Before function")
        func()
        print("After function")
    return wrapper

@decorator
def training():
    print("Data Science!")

training()
# Out:
# Before function
# Data Science!
# After function

# %% [markdown]
# **B5**
#
# A lambda function is a small, anonymous function defined with the lambda keyword, allowing for concise function creation without a formal declaration.
#
# Characteristics->
# Anonymous: Lambda functions don’t have a name.
# Single Expression: They can only contain a single expression.
#
# Use Cases:
# Lambda functions are often used for short, throwaway functions, typically with functions like map(), filter(), or sorted().

# %%
#simple lambda function to add two numbers
add = lambda x, y: x + y

# Using the lambda function
result = add(5, 3)
print(result)

# Using lambda with filter to get even numbers from a list
numbers = [1, 2, 3, 4, 5, 6]
even_numbers = list(filter(lambda x: x % 2 == 0, numbers))
print(even_numbers)
# Out:
# 8
# [2, 4, 6]

# %% [markdown]
# **B6**
#
# Python handles multithreading using the threading module, but due to the Global Interpreter Lock, only one thread can execute Python bytecode at a time, limiting the performance benefits of multithreading for CPU-bound tasks.
#
# Key Differences ->
# Multithreading: Uses multiple threads within a single process, sharing memory space, which is effective for I/O-bound tasks.
#
# Multiprocessing: Creates multiple processes, each with its own Python interpreter and memory space, making it suitable for CPU-bound tasks.

# %%
#multithreading

import threading
import time

def print_numbers():
    for i in range(5):
        time.sleep(1)
        print(i)

thread = threading.Thread(target=print_numbers)
thread.start()
thread.join()
print("Thread finished execution.")

# multiprocessing

import multiprocessing
import time

def print_numbers():
    for i in range(5):
        time.sleep(1)
        print(i)

if __name__ == "__main__":
    process = multiprocessing.Process(target=print_numbers)
    process.start()
    process.join()
    print("Process finished execution.")
# Out:
# 0
# 1
# 2
# 3
# 4
# Thread finished execution.
# 0
# 1
# 2
# 3
# 4
# Process finished execution.

# %% [markdown]
# **B7**
#
#  In Python, will work with files using built-in functions such as open(), read(), and write(), which allow you to perform various operations like writing to files.
#
# File Modes ->
#
# 'r': Read (default mode)
#
# 'w': Write (overwrites the file)
#
# 'a': Append (adds to the end of the file)
#
# 'b': Binary mode
#
# 't': Text mode (default)

# %%
# Writing to a file
with open('example.txt', 'w') as file:
    file.write("Hello, World!\n")

# Reading from a file
with open('example.txt', 'r') as file:
    content = file.read()
    print(content)
# Out:
# Hello, World!

# %% [markdown]
# **OOPImplementation**
#
# **B1**
#
# Object-Oriented Programming (OOP) is a programming paradigm that uses "objects" to represent data and methods, promoting modularity and code reusability.
#
# Basic Principles of OOP:
#
# **Encapsulation:** Bundling data and methods within a class, restricting direct access to some of the object's components.
#
# **Abstraction:** Hiding complex implementation details and exposing only the necessary features of an object.
#
# **Inheritance:** bold text Allowing a new class to inherit properties and behaviors from an existing class, promoting code reuse.
#
# **Polymorphism:** Enabling objects to be treated as instances of their parent class, with the ability to override methods for specific behaviors.

# %% [markdown]
# **B2**
#
# Class is a blueprint for creating objects, defining properties and behaviors, while an object is an instance of a class, encapsulating the class's attributes and methods.

# %%
# Define a class
class Dog:
    def __init__(self, name):
        self.name = name

    def bark(self):
        return f"{self.name} says Woof!"

my_dog = Dog("Buddy")
print(my_dog.bark())
# Out:
# Buddy says Woof!

# %% [markdown]
# **B3**
#
# To create a class in Python, use the class keyword followed by the class name and a colon.

# %%
# Creating a class
class Car:
    def __init__(self, make, model):
        self.make = make
        self.model = model

    def display_info(self):
        return f"Car: {self.make} {self.model}"

# creating an object of the class
my_car = Car("Toyota", "Corolla")

# accessing the object's method
print(my_car.display_info())
# Out:
# Car: Toyota Corolla

# %% [markdown]
# **B4:**
#
# Instance variables are specific to each instance of a class, defined within methods using self, while class variables are shared across all instances of a class and are defined directly within the class.

# %%
class Dog:
    species = "Canine"  # Class variable

    def __init__(self, name):
        self.name = name  # Instance variable

# Creating instances
dog1 = Dog("Buddy")
dog2 = Dog("Max")

# Accessing instance and class variables
print(dog1.name)
print(dog2.name)
print(Dog.species)
print(dog1.species)
print(dog2.species)

# Modifying the class variable
Dog.species = "Wolf"
print(dog1.species)
print(dog2.species)
# Out:
# Buddy
# Max
# Canine
# Canine
# Canine
# Wolf
# Wolf

# %% [markdown]
# **B5: **
#
# __init__ method in Python is a constructor used to initialize newly created objects, setting their initial state and attributes.

# %%
class Person:
    def __init__(self, name, age):  # constructor
        self.name = name  # instance variable
        self.age = age

# creating object
person1 = Person("Alice", 30)

# accessing object attributes
print(f"Name: {person1.name}, Age: {person1.age}")
# Out:
# Name: Alice, Age: 30

# %% [markdown]
# **B6**
#
# self refers to the instance, and cls refers to the class itself

# %%
class Example:
  def instance_method(self):
    pass
  @classmethod
  def class_method(cls):
    pass

# %% [markdown]
# **B7**
#
# Inheritance allows one class to inherit attributes and methods from another.

# %%
class Animal:
    def speak(self):
        return "Animal speaks"

class Dog(Animal):
    def bark(self):
        return "Dog barks"

my_dog = Dog()
print(my_dog.speak())
print(my_dog.bark())
# Out:
# Animal speaks
# Dog barks

# %% [markdown]
# **B8:**
#
# Method overriding occurs when a subclass provides a specific implementation of a method that is already defined in its superclass, changing its functionality, while method overloading involves creating multiple methods with the same name but different parameters within the same class, allowing for different functionalities based on the input.

# %%
#method overriding

class Animal:
    def sound(self):
        return "Animal makes a sound"

class Dog(Animal):
    def sound(self):
        return "Dog barks"

my_dog = Dog()
print(my_dog.sound())

#method overloading
class Calculator:
    def add(self, a, b, c=0):
        return a + b + c

# Creating an object
calc = Calculator()
print(calc.add(2, 3))
print(calc.add(2, 3, 4))
# Out:
# Dog barks
# 5
# 9

# %% [markdown]
# **B9:**
#
# Multiple inheritance is a feature in Python that allows a class to inherit from more than one parent class, enabling the combination of behaviors and attributes from multiple sources.
#
# Python uses the Method Resolution Order (MRO) to determine the order in which classes are looked up when searching for a method. The MRO helps to resolve conflicts when a method is present in multiple parent classes.

# %%
class Parent1:
    def greet(self):
        return "Hello from Parent1"

class Parent2:
    def greet(self):
        return "Hello from Parent2"

class Child(Parent1, Parent2):
    pass

child = Child()
print(child.greet())

#MRO
print(Child.__mro__)
# Out:
# Hello from Parent1
# (<class '__main__.Child'>, <class '__main__.Parent1'>, <class '__main__.Parent2'>, <class 'object'>)

# %% [markdown]
# **B10:**
#
# Abstract classes are classes that cannot be instantiated and are meant to be subclassed, providing a common interface for derived classes. They can define abstract methods that must be implemented by any non-abstract subclass.
#
# Interfaces can be seen as a type of abstract class that only defines methods without any implementation.
#
# The abc module provides the ABC class and the abstractmethod decorator to define abstract base classes.

# %%
from abc import ABC, abstractmethod

class Shape(ABC):  # Abstract class
    @abstractmethod
    def area(self):  # Abstract method
        pass

class Circle(Shape):  # Concrete class
    def __init__(self, radius):
        self.radius = radius

    def area(self):  # Implementing abstract method
        return 3.14 * self.radius ** 2

# Creating an object of Circle
circle = Circle(5)
print(circle.area())
# Out:
# 78.5

# %% [markdown]
# **B11**
#
# # Polymorphism in Python allows different objects to be accessed through the same interface, enabling methods to be called on objects of different types, often through method overriding.

# %%
class Bird:
    def fly(self):
        return "Flies in the sky"

class Airplane:
    def fly(self):
        return "Soars through the clouds"

def perform_flight(obj):
    print(obj.fly())

sparrow = Bird()
boeing = Airplane()

perform_flight(sparrow)
perform_flight(boeing)
# Out:
# Flies in the sky
# Soars through the clouds

# %% [markdown]
# **B12**
#
# Encapsulation in OOP is the concept of restricting direct access to an object's internal state and requiring all interaction to be performed through well-defined methods.
#
# Encapsulation hides internal details by making certain attributes private and only allowing access through public methods, ensuring controlled interaction with an object's state.

# %%
class BankAccount:
    def __init__(self):
        self.__balance = 0  # private variable

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount  # modify private variable

    def get_balance(self):  # public method to access private variable
        return self.__balance

account = BankAccount()
account.deposit(100)

print(account.get_balance())
# Out:
# 100

# %% [markdown]
# **B13**
#
# By Using @property decorator to define getter and setter methods.

# %%
class Car:
    def __init__(self):
        self._model = None
    @property
    def model(self):
        return self._model
    @model.setter
    def model(self, value):
        self._model = value

# %% [markdown]
# **B14**
#
# Operator overloading in Python allows you to define custom behavior for operators -> +, -, etc., for user-defined classes by implementing special methods such as __add__, __sub__, etc.

# %%
class Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        return Point(self.x + other.x, self.y + other.y)

    def __sub__(self, other):
        return Point(self.x - other.x, self.y - other.y)

    def __repr__(self):
        return f"Point({self.x}, {self.y})"

p1 = Point(2, 3)
p2 = Point(5, 7)

# Using overloaded operators
p3 = p1 + p2
p4 = p1 - p2

print(p3)
print(p4)
# Out:
# Point(7, 10)
# Point(-3, -4)

# %% [markdown]
# **B15**
#
# Static methods don't require an instance, class methods work with the class.

# %%
class Name:
  @staticmethod
  def training():
    print('Meta Scifor Technology!..')
  @classmethod
  def training(cls):
    return cls()
